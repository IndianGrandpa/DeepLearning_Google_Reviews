# %% [markdown]
# Install `google-play-scraper` package using: `pip install google-play-scraper`
#
#
# Please refer to https://pypi.org/project/google-play-scraper/ for details.

# %%
# %pip install google_play_scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.comNote: you may need to restart the kernel to use updated packages.
# Collecting google_play_scraper
#
#   Downloading google_play_scraper-1.2.2-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.2

# %%
from google_play_scraper import Sort, reviews,reviews_all
import pandas as pd

# %%
# initialization

app_name = 'com.whatsapp' # found in app's url

rvws, token = reviews(
    app_name,           # found in app's url
    lang='en',        # defaults to 'en'
    country='us',     # defaults to 'us'
    sort=Sort.NEWEST, # start with most recent
    count=200       # batch size, set as 200 since 200 reviews per page
)

app_reviews = rvws
batch_num=1

# %%
# Loop through the number of batches
for batch in range(100): # You can adjust the number of batches to collect more or less reviews
    rvws, token = reviews( # store continuation_token
        app_name,
        lang='en',
        country='us',
        sort=Sort.NEWEST,
        count=200,
        # using token obtained from previous batch
        continuation_token=token
    )
    app_reviews.extend(rvws)
    batch_num +=1

# %%
df = pd.DataFrame.from_records(app_reviews)
df
# Out:
#                                     reviewId           userName  \
# 0       91f319c6-24ae-4664-98ca-9d15b239ce2f    Sureshsura Sura
# 1       562479c0-0a88-4df2-a9df-eae16dccd91a      SHIKHAR GUPTA
# 2       41d65e55-b348-4f23-b73b-9c84be667e7f       Danìel mbuzi
# 3       723379be-247d-422f-9c0d-d08d8ec5c9a1       Rajput Singh
# 4       d6f291e6-074f-4b67-8464-a9e31484d10a     Muhammad Zaman
# ...                                      ...                ...
# 149395  8bcde390-6870-4c06-807d-901fd3d991ca  Arinaitwe Clinton
# 149396  91a9ecb4-f76c-473e-8ecd-b4228fc9ed52       Cedric Jempa
# 149397  3949eb16-478c-419c-b5b2-5e7a098d4425     Lilian Maspala
# 149398  ad1d1e98-8b05-4cc6-9adb-388d9ea57421  McPherson Onochie
# 149399  6d65e1a2-310f-466c-9520-90bff7d4e8f8       Rakho Rhakho
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a/AEdFTp...
# 1       https://play-lh.googleusercontent.com/a-/AD5-W...
# 2       https://play-lh.googleusercontent.com/a/AEdFTp...
# 3       https://play-lh.googleusercontent.com/a/AEdFTp...
# 4       https://play-lh.googleusercontent.com/a-/AD5-W...
# ...                                                   ...
# 149395  https://play-lh.googleusercontent.com/a/AEdFTp...
# 149396  https://play-lh.googleusercontent.com/a/AEdFTp...
# 149397  https://play-lh.googleusercontent.com/a/AEdFTp...
# 149398  https://play-lh.googleusercontent.com/a-/AD5-W...
# 149399  https://play-lh.googleusercontent.com/a/AEdFTp...
#
#                                                   content  score  \
# 0                                          K.dhanalakshmi      5
# 1       Calls and video call is so poor condition call...      1
# 2                                             Easy to use      5
# 3                         Very useful and mindblowing app      5
# 4                                               Wonderful      5
# ...                                                   ...    ...
# 149395               Why is this app refusing to download      1
# 149396                                          Very good      3
# 149397                                               Nice      5
# 149398                                  Great app Love it      5
# 149399                                                A 💪      5
#
#         thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                   0                 None 2023-01-19 01:32:56         None
# 1                   0           2.22.24.78 2023-01-19 01:32:44         None
# 2                   0           2.22.15.74 2023-01-19 01:32:24         None
# 3                   0                 None 2023-01-19 01:32:08         None
# 4                   0           2.22.23.84 2023-01-19 01:31:31         None
# ...               ...                  ...                 ...          ...
# 149395              0                 None 2022-12-04 01:40:25         None
# 149396              0                 None 2022-12-04 01:39:30         None
# 149397              0                 None 2022-12-04 01:39:11         None
# 149398              0           2.21.18.17 2022-12-04 01:38:59         None
# 149399              0            2.21.8.17 2022-12-04 01:38:46         None
#
#        repliedAt
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# ...          ...
# 149395      None
# 149396      None
# 149397      None
# 149398      None
# 149399      None
#
# [149400 rows x 10 columns]

# %%
df.to_csv('whatsapp_reviews.csv',index=False)

# %%
df.score.value_counts()
# Out:
# 5    93767
# 1    24482
# 4    14435
# 3     9570
# 2     7146
# Name: score, dtype: int64
