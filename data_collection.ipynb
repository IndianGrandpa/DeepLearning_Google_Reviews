# %% [markdown]
# Install `google-play-scraper` package using: `pip install google-play-scraper`
#
#
# Please refer to https://pypi.org/project/google-play-scraper/ for details.

# %%
# %pip install google_play_scraper
# Out:
# Looking in indexes: https://pypi.org/simple, https://pypi.ngc.nvidia.com
# Collecting google_play_scraper
#   Downloading google_play_scraper-1.2.3-py3-none-any.whl (28 kB)
# Installing collected packages: google_play_scraper
# Successfully installed google_play_scraper-1.2.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from google_play_scraper import Sort, reviews,reviews_all
import pandas as pd

# %%
# initialization

app_name = 'com.whatsapp' # found in app's url

rvws, token = reviews(
    app_name,           # found in app's url
    lang='en',        # defaults to 'en'
    country='us',     # defaults to 'us'
    sort=Sort.NEWEST, # start with most recent
    count=200       # batch size, set as 200 since 200 reviews per page
)

app_reviews = rvws
batch_num=1

# %%
# Loop through the number of batches
for batch in range(2000): # You can adjust the number of batches to collect more or less reviews
    
    rvws, token = reviews( # store continuation_token
        app_name,
        lang='en',
        country='us',
        sort=Sort.NEWEST,
        count=200,
        # using token obtained from previous batch
        continuation_token=token
    )
    app_reviews.extend(rvws)
    batch_num +=1
    print("batch_done:",batch)
# Out:
# batch_done: 0
# batch_done: 1
# batch_done: 2
# batch_done: 3
# batch_done: 4
# batch_done: 5
# batch_done: 6
# batch_done: 7
# batch_done: 8
# batch_done: 9
# batch_done: 10
# batch_done: 11
# batch_done: 12
# batch_done: 13
# batch_done: 14
# batch_done: 15
# batch_done: 16
# batch_done: 17
# batch_done: 18
# batch_done: 19
# batch_done: 20
# batch_done: 21
# batch_done: 22
# batch_done: 23
# batch_done: 24
# batch_done: 25
# batch_done: 26
# batch_done: 27
# batch_done: 28
# batch_done: 29
# batch_done: 30
# batch_done: 31
# batch_done: 32
# batch_done: 33
# batch_done: 34
# batch_done: 35
# batch_done: 36
# batch_done: 37
# batch_done: 38
# batch_done: 39
# batch_done: 40
# batch_done: 41
# batch_done: 42
# batch_done: 43
# batch_done: 44
# batch_done: 45
# batch_done: 46
# batch_done: 47
# batch_done: 48
# batch_done: 49
# batch_done: 50
# batch_done: 51
# batch_done: 52
# batch_done: 53
# batch_done: 54
# batch_done: 55
# batch_done: 56
# batch_done: 57
# batch_done: 58
# batch_done: 59
# batch_done: 60
# batch_done: 61
# batch_done: 62
# batch_done: 63
# batch_done: 64
# batch_done: 65
# batch_done: 66
# batch_done: 67
# batch_done: 68
# batch_done: 69
# batch_done: 70
# batch_done: 71
# batch_done: 72
# batch_done: 73
# batch_done: 74
# batch_done: 75
# batch_done: 76
# batch_done: 77
# batch_done: 78
# batch_done: 79
# batch_done: 80
# batch_done: 81
# batch_done: 82
# batch_done: 83
# batch_done: 84
# batch_done: 85
# batch_done: 86
# batch_done: 87
# batch_done: 88
# batch_done: 89
# batch_done: 90
# batch_done: 91
# batch_done: 92
# batch_done: 93
# batch_done: 94
# batch_done: 95
# batch_done: 96
# batch_done: 97
# batch_done: 98
# batch_done: 99
# batch_done: 100
# batch_done: 101
# batch_done: 102
# batch_done: 103
# batch_done: 104
# batch_done: 105
# batch_done: 106
# batch_done: 107
# batch_done: 108
# batch_done: 109
# batch_done: 110
# batch_done: 111
# batch_done: 112
# batch_done: 113
# batch_done: 114
# batch_done: 115
# batch_done: 116
# batch_done: 117
# batch_done: 118
# batch_done: 119
# batch_done: 120
# batch_done: 121
# batch_done: 122
# batch_done: 123
# batch_done: 124
# batch_done: 125
# batch_done: 126
# batch_done: 127
# batch_done: 128
# batch_done: 129
# batch_done: 130
# batch_done: 131
# batch_done: 132
# batch_done: 133
# batch_done: 134
# batch_done: 135
# batch_done: 136
# batch_done: 137
# batch_done: 138
# batch_done: 139
# batch_done: 140
# batch_done: 141
# batch_done: 142
# batch_done: 143
# batch_done: 144
# batch_done: 145
# batch_done: 146
# batch_done: 147
# batch_done: 148
# batch_done: 149
# batch_done: 150
# batch_done: 151
# batch_done: 152
# batch_done: 153
# batch_done: 154
# batch_done: 155
# batch_done: 156
# batch_done: 157
# batch_done: 158
# batch_done: 159
# batch_done: 160
# batch_done: 161
# batch_done: 162
# batch_done: 163
# batch_done: 164
# batch_done: 165
# batch_done: 166
# batch_done: 167
# batch_done: 168
# batch_done: 169
# batch_done: 170
# batch_done: 171
# batch_done: 172
# batch_done: 173
# batch_done: 174
# batch_done: 175
# batch_done: 176
# batch_done: 177
# batch_done: 178
# batch_done: 179
# batch_done: 180
# batch_done: 181
# batch_done: 182
# batch_done: 183
# batch_done: 184
# batch_done: 185
# batch_done: 186
# batch_done: 187
# batch_done: 188
# batch_done: 189
# batch_done: 190
# batch_done: 191
# batch_done: 192
# batch_done: 193
# batch_done: 194
# batch_done: 195
# batch_done: 196
# batch_done: 197
# batch_done: 198
# batch_done: 199
# batch_done: 200
# batch_done: 201
# batch_done: 202
# batch_done: 203
# batch_done: 204
# batch_done: 205
# batch_done: 206
# batch_done: 207
# batch_done: 208
# batch_done: 209
# batch_done: 210
# batch_done: 211
# batch_done: 212
# batch_done: 213
# batch_done: 214
# batch_done: 215
# batch_done: 216
# batch_done: 217
# batch_done: 218
# batch_done: 219
# batch_done: 220
# batch_done: 221
# batch_done: 222
# batch_done: 223
# batch_done: 224
# batch_done: 225
# batch_done: 226
# batch_done: 227
# batch_done: 228
# batch_done: 229
# batch_done: 230
# batch_done: 231
# batch_done: 232
# batch_done: 233
# batch_done: 234
# batch_done: 235
# batch_done: 236
# batch_done: 237
# batch_done: 238
# batch_done: 239
# batch_done: 240
# batch_done: 241
# batch_done: 242
# batch_done: 243
# batch_done: 244
# batch_done: 245
# batch_done: 246
# batch_done: 247
# batch_done: 248
# batch_done: 249
# batch_done: 250
# batch_done: 251
# batch_done: 252
# batch_done: 253
# batch_done: 254
# batch_done: 255
# batch_done: 256
# batch_done: 257
# batch_done: 258
# batch_done: 259
# batch_done: 260
# batch_done: 261
# batch_done: 262
# batch_done: 263
# batch_done: 264
# batch_done: 265
# batch_done: 266
# batch_done: 267
# batch_done: 268
# batch_done: 269
# batch_done: 270
# batch_done: 271
# batch_done: 272
# batch_done: 273
# batch_done: 274
# batch_done: 275
# batch_done: 276
# batch_done: 277
# batch_done: 278
# batch_done: 279
# batch_done: 280
# batch_done: 281
# batch_done: 282
# batch_done: 283
# batch_done: 284
# batch_done: 285
# batch_done: 286
# batch_done: 287
# batch_done: 288
# batch_done: 289
# batch_done: 290
# batch_done: 291
# batch_done: 292
# batch_done: 293
# batch_done: 294
# batch_done: 295
# batch_done: 296
# batch_done: 297
# batch_done: 298
# batch_done: 299
# batch_done: 300
# batch_done: 301
# batch_done: 302
# batch_done: 303
# batch_done: 304
# batch_done: 305
# batch_done: 306
# batch_done: 307
# batch_done: 308
# batch_done: 309
# batch_done: 310
# batch_done: 311
# batch_done: 312
# batch_done: 313
# batch_done: 314
# batch_done: 315
# batch_done: 316
# batch_done: 317
# batch_done: 318
# batch_done: 319
# batch_done: 320
# batch_done: 321
# batch_done: 322
# batch_done: 323
# batch_done: 324
# batch_done: 325
# batch_done: 326
# batch_done: 327
# batch_done: 328
# batch_done: 329
# batch_done: 330
# batch_done: 331
# batch_done: 332
# batch_done: 333
# batch_done: 334
# batch_done: 335
# batch_done: 336
# batch_done: 337
# batch_done: 338
# batch_done: 339
# batch_done: 340
# batch_done: 341
# batch_done: 342
# batch_done: 343
# batch_done: 344
# batch_done: 345
# batch_done: 346
# batch_done: 347
# batch_done: 348
# batch_done: 349
# batch_done: 350
# batch_done: 351
# batch_done: 352
# batch_done: 353
# batch_done: 354
# batch_done: 355
# batch_done: 356
# batch_done: 357
# batch_done: 358
# batch_done: 359
# batch_done: 360
# batch_done: 361
# batch_done: 362
# batch_done: 363
# batch_done: 364
# batch_done: 365
# batch_done: 366
# batch_done: 367
# batch_done: 368
# batch_done: 369
# batch_done: 370
# batch_done: 371
# batch_done: 372
# batch_done: 373
# batch_done: 374
# batch_done: 375
# batch_done: 376
# batch_done: 377
# batch_done: 378
# batch_done: 379
# batch_done: 380
# batch_done: 381
# batch_done: 382
# batch_done: 383
# batch_done: 384
# batch_done: 385
# batch_done: 386
# batch_done: 387
# batch_done: 388
# batch_done: 389
# batch_done: 390
# batch_done: 391
# batch_done: 392
# batch_done: 393
# batch_done: 394
# batch_done: 395
# batch_done: 396
# batch_done: 397
# batch_done: 398
# batch_done: 399
# batch_done: 400
# batch_done: 401
# batch_done: 402
# batch_done: 403
# batch_done: 404
# batch_done: 405
# batch_done: 406
# batch_done: 407
# batch_done: 408
# batch_done: 409
# batch_done: 410
# batch_done: 411
# batch_done: 412
# batch_done: 413
# batch_done: 414
# batch_done: 415
# batch_done: 416
# batch_done: 417
# batch_done: 418
# batch_done: 419
# batch_done: 420
# batch_done: 421
# batch_done: 422
# batch_done: 423
# batch_done: 424
# batch_done: 425
# batch_done: 426
# batch_done: 427
# batch_done: 428
# batch_done: 429
# batch_done: 430
# batch_done: 431
# batch_done: 432
# batch_done: 433
# batch_done: 434
# batch_done: 435
# batch_done: 436
# batch_done: 437
# batch_done: 438
# batch_done: 439
# batch_done: 440
# batch_done: 441
# batch_done: 442
# batch_done: 443
# batch_done: 444
# batch_done: 445
# batch_done: 446
# batch_done: 447
# batch_done: 448
# batch_done: 449
# batch_done: 450
# batch_done: 451
# batch_done: 452
# batch_done: 453
# batch_done: 454
# batch_done: 455
# batch_done: 456
# batch_done: 457
# batch_done: 458
# batch_done: 459
# batch_done: 460
# batch_done: 461
# batch_done: 462
# batch_done: 463
# batch_done: 464
# batch_done: 465
# batch_done: 466
# batch_done: 467
# batch_done: 468
# batch_done: 469
# batch_done: 470
# batch_done: 471
# batch_done: 472
# batch_done: 473
# batch_done: 474
# batch_done: 475
# batch_done: 476
# batch_done: 477
# batch_done: 478
# batch_done: 479
# batch_done: 480
# batch_done: 481
# batch_done: 482
# batch_done: 483
# batch_done: 484
# batch_done: 485
# batch_done: 486
# batch_done: 487
# batch_done: 488
# batch_done: 489
# batch_done: 490
# batch_done: 491
# batch_done: 492
# batch_done: 493
# batch_done: 494
# batch_done: 495
# batch_done: 496
# batch_done: 497
# batch_done: 498
# batch_done: 499
# batch_done: 500
# batch_done: 501
# batch_done: 502
# batch_done: 503
# batch_done: 504
# batch_done: 505
# batch_done: 506
# batch_done: 507
# batch_done: 508
# batch_done: 509
# batch_done: 510
# batch_done: 511
# batch_done: 512
# batch_done: 513
# batch_done: 514
# batch_done: 515
# batch_done: 516
# batch_done: 517
# batch_done: 518
# batch_done: 519
# batch_done: 520
# batch_done: 521
# batch_done: 522
# batch_done: 523
# batch_done: 524
# batch_done: 525
# batch_done: 526
# batch_done: 527
# batch_done: 528
# batch_done: 529
# batch_done: 530
# batch_done: 531
# batch_done: 532
# batch_done: 533
# batch_done: 534
# batch_done: 535
# batch_done: 536
# batch_done: 537
# batch_done: 538
# batch_done: 539
# batch_done: 540
# batch_done: 541
# batch_done: 542
# batch_done: 543
# batch_done: 544
# batch_done: 545
# batch_done: 546
# batch_done: 547
# batch_done: 548
# batch_done: 549
# batch_done: 550
# batch_done: 551
# batch_done: 552
# batch_done: 553
# batch_done: 554
# batch_done: 555
# batch_done: 556
# batch_done: 557
# batch_done: 558
# batch_done: 559
# batch_done: 560
# batch_done: 561
# batch_done: 562
# batch_done: 563
# batch_done: 564
# batch_done: 565
# batch_done: 566
# batch_done: 567
# batch_done: 568
# batch_done: 569
# batch_done: 570
# batch_done: 571
# batch_done: 572
# batch_done: 573
# batch_done: 574
# batch_done: 575
# batch_done: 576
# batch_done: 577
# batch_done: 578
# batch_done: 579
# batch_done: 580
# batch_done: 581
# batch_done: 582
# batch_done: 583
# batch_done: 584
# batch_done: 585
# batch_done: 586
# batch_done: 587
# batch_done: 588
# batch_done: 589
# batch_done: 590
# batch_done: 591
# batch_done: 592
# batch_done: 593
# batch_done: 594
# batch_done: 595
# batch_done: 596
# batch_done: 597
# batch_done: 598
# batch_done: 599
# batch_done: 600
# batch_done: 601
# batch_done: 602
# batch_done: 603
# batch_done: 604
# batch_done: 605
# batch_done: 606
# batch_done: 607
# batch_done: 608
# batch_done: 609
# batch_done: 610
# batch_done: 611
# batch_done: 612
# batch_done: 613
# batch_done: 614
# batch_done: 615
# batch_done: 616
# batch_done: 617
# batch_done: 618
# batch_done: 619
# batch_done: 620
# batch_done: 621
# batch_done: 622
# batch_done: 623
# batch_done: 624
# batch_done: 625
# batch_done: 626
# batch_done: 627
# batch_done: 628
# batch_done: 629
# batch_done: 630
# batch_done: 631
# batch_done: 632
# batch_done: 633
# batch_done: 634
# batch_done: 635
# batch_done: 636
# batch_done: 637
# batch_done: 638
# batch_done: 639
# batch_done: 640
# batch_done: 641
# batch_done: 642
# batch_done: 643
# batch_done: 644
# batch_done: 645
# batch_done: 646
# batch_done: 647
# batch_done: 648
# batch_done: 649
# batch_done: 650
# batch_done: 651
# batch_done: 652
# batch_done: 653
# batch_done: 654
# batch_done: 655
# batch_done: 656
# batch_done: 657
# batch_done: 658
# batch_done: 659
# batch_done: 660
# batch_done: 661
# batch_done: 662
# batch_done: 663
# batch_done: 664
# batch_done: 665
# batch_done: 666
# batch_done: 667
# batch_done: 668
# batch_done: 669
# batch_done: 670
# batch_done: 671
# batch_done: 672
# batch_done: 673
# batch_done: 674
# batch_done: 675
# batch_done: 676
# batch_done: 677
# batch_done: 678
# batch_done: 679
# batch_done: 680
# batch_done: 681
# batch_done: 682
# batch_done: 683
# batch_done: 684
# batch_done: 685
# batch_done: 686
# batch_done: 687
# batch_done: 688
# batch_done: 689
# batch_done: 690
# batch_done: 691
# batch_done: 692
# batch_done: 693
# batch_done: 694
# batch_done: 695
# batch_done: 696
# batch_done: 697
# batch_done: 698
# batch_done: 699
# batch_done: 700
# batch_done: 701
# batch_done: 702
# batch_done: 703
# batch_done: 704
# batch_done: 705
# batch_done: 706
# batch_done: 707
# batch_done: 708
# batch_done: 709
# batch_done: 710
# batch_done: 711
# batch_done: 712
# batch_done: 713
# batch_done: 714
# batch_done: 715
# batch_done: 716
# batch_done: 717
# batch_done: 718
# batch_done: 719
# batch_done: 720
# batch_done: 721
# batch_done: 722
# batch_done: 723
# batch_done: 724
# batch_done: 725
# batch_done: 726
# batch_done: 727
# batch_done: 728
# batch_done: 729
# batch_done: 730
# batch_done: 731
# batch_done: 732
# batch_done: 733
# batch_done: 734
# batch_done: 735
# batch_done: 736
# batch_done: 737
# batch_done: 738
# batch_done: 739
# batch_done: 740
# batch_done: 741
# batch_done: 742
# batch_done: 743
# batch_done: 744
# batch_done: 745
# batch_done: 746
# batch_done: 747
# batch_done: 748
# batch_done: 749
# batch_done: 750
# batch_done: 751
# batch_done: 752
# batch_done: 753
# batch_done: 754
# batch_done: 755
# batch_done: 756
# batch_done: 757
# batch_done: 758
# batch_done: 759
# batch_done: 760
# batch_done: 761
# batch_done: 762
# batch_done: 763
# batch_done: 764
# batch_done: 765
# batch_done: 766
# batch_done: 767
# batch_done: 768
# batch_done: 769
# batch_done: 770
# batch_done: 771
# batch_done: 772
# batch_done: 773
# batch_done: 774
# batch_done: 775
# batch_done: 776
# batch_done: 777
# batch_done: 778
# batch_done: 779
# batch_done: 780
# batch_done: 781
# batch_done: 782
# batch_done: 783
# batch_done: 784
# batch_done: 785
# batch_done: 786
# batch_done: 787
# batch_done: 788
# batch_done: 789
# batch_done: 790
# batch_done: 791
# batch_done: 792
# batch_done: 793
# batch_done: 794
# batch_done: 795
# batch_done: 796
# batch_done: 797
# batch_done: 798
# batch_done: 799
# batch_done: 800
# batch_done: 801
# batch_done: 802
# batch_done: 803
# batch_done: 804
# batch_done: 805
# batch_done: 806
# batch_done: 807
# batch_done: 808
# batch_done: 809
# batch_done: 810
# batch_done: 811
# batch_done: 812
# batch_done: 813
# batch_done: 814
# batch_done: 815
# batch_done: 816
# batch_done: 817
# batch_done: 818
# batch_done: 819
# batch_done: 820
# batch_done: 821
# batch_done: 822
# batch_done: 823
# batch_done: 824
# batch_done: 825
# batch_done: 826
# batch_done: 827
# batch_done: 828
# batch_done: 829
# batch_done: 830
# batch_done: 831
# batch_done: 832
# batch_done: 833
# batch_done: 834
# batch_done: 835
# batch_done: 836
# batch_done: 837
# batch_done: 838
# batch_done: 839
# batch_done: 840
# batch_done: 841
# batch_done: 842
# batch_done: 843
# batch_done: 844
# batch_done: 845
# batch_done: 846
# batch_done: 847
# batch_done: 848
# batch_done: 849
# batch_done: 850
# batch_done: 851
# batch_done: 852
# batch_done: 853
# batch_done: 854
# batch_done: 855
# batch_done: 856
# batch_done: 857
# batch_done: 858
# batch_done: 859
# batch_done: 860
# batch_done: 861
# batch_done: 862
# batch_done: 863
# batch_done: 864
# batch_done: 865
# batch_done: 866
# batch_done: 867
# batch_done: 868
# batch_done: 869
# batch_done: 870
# batch_done: 871
# batch_done: 872
# batch_done: 873
# batch_done: 874
# batch_done: 875
# batch_done: 876
# batch_done: 877
# batch_done: 878
# batch_done: 879
# batch_done: 880
# batch_done: 881
# batch_done: 882
# batch_done: 883
# batch_done: 884
# batch_done: 885
# batch_done: 886
# batch_done: 887
# batch_done: 888
# batch_done: 889
# batch_done: 890
# batch_done: 891
# batch_done: 892
# batch_done: 893
# batch_done: 894
# batch_done: 895
# batch_done: 896
# batch_done: 897
# batch_done: 898
# batch_done: 899
# batch_done: 900
# batch_done: 901
# batch_done: 902
# batch_done: 903
# batch_done: 904
# batch_done: 905
# batch_done: 906
# batch_done: 907
# batch_done: 908
# batch_done: 909
# batch_done: 910
# batch_done: 911
# batch_done: 912
# batch_done: 913
# batch_done: 914
# batch_done: 915
# batch_done: 916
# batch_done: 917
# batch_done: 918
# batch_done: 919
# batch_done: 920
# batch_done: 921
# batch_done: 922
# batch_done: 923
# batch_done: 924
# batch_done: 925
# batch_done: 926
# batch_done: 927
# batch_done: 928
# batch_done: 929
# batch_done: 930
# batch_done: 931
# batch_done: 932
# batch_done: 933
# batch_done: 934
# batch_done: 935
# batch_done: 936
# batch_done: 937
# batch_done: 938
# batch_done: 939
# batch_done: 940
# batch_done: 941
# batch_done: 942
# batch_done: 943
# batch_done: 944
# batch_done: 945
# batch_done: 946
# batch_done: 947
# batch_done: 948
# batch_done: 949
# batch_done: 950
# batch_done: 951
# batch_done: 952
# batch_done: 953
# batch_done: 954
# batch_done: 955
# batch_done: 956
# batch_done: 957
# batch_done: 958
# batch_done: 959
# batch_done: 960
# batch_done: 961
# batch_done: 962
# batch_done: 963
# batch_done: 964
# batch_done: 965
# batch_done: 966
# batch_done: 967
# batch_done: 968
# batch_done: 969
# batch_done: 970
# batch_done: 971
# batch_done: 972
# batch_done: 973
# batch_done: 974
# batch_done: 975
# batch_done: 976
# batch_done: 977
# batch_done: 978
# batch_done: 979
# batch_done: 980
# batch_done: 981
# batch_done: 982
# batch_done: 983
# batch_done: 984
# batch_done: 985
# batch_done: 986
# batch_done: 987
# batch_done: 988
# batch_done: 989
# batch_done: 990
# batch_done: 991
# batch_done: 992
# batch_done: 993
# batch_done: 994
# batch_done: 995
# batch_done: 996
# batch_done: 997
# batch_done: 998
# batch_done: 999
# batch_done: 1000
# batch_done: 1001
# batch_done: 1002
# batch_done: 1003
# batch_done: 1004
# batch_done: 1005
# batch_done: 1006
# batch_done: 1007
# batch_done: 1008
# batch_done: 1009
# batch_done: 1010
# batch_done: 1011
# batch_done: 1012
# batch_done: 1013
# batch_done: 1014
# batch_done: 1015
# batch_done: 1016
# batch_done: 1017
# batch_done: 1018
# batch_done: 1019
# batch_done: 1020
# batch_done: 1021
# batch_done: 1022
# batch_done: 1023
# batch_done: 1024
# batch_done: 1025
# batch_done: 1026
# batch_done: 1027
# batch_done: 1028
# batch_done: 1029
# batch_done: 1030
# batch_done: 1031
# batch_done: 1032
# batch_done: 1033
# batch_done: 1034
# batch_done: 1035
# batch_done: 1036
# batch_done: 1037
# batch_done: 1038
# batch_done: 1039
# batch_done: 1040
# batch_done: 1041
# batch_done: 1042
# batch_done: 1043
# batch_done: 1044
# batch_done: 1045
# batch_done: 1046
# batch_done: 1047
# batch_done: 1048
# batch_done: 1049
# batch_done: 1050
# batch_done: 1051
# batch_done: 1052
# batch_done: 1053
# batch_done: 1054
# batch_done: 1055
# batch_done: 1056
# batch_done: 1057
# batch_done: 1058
# batch_done: 1059
# batch_done: 1060
# batch_done: 1061
# batch_done: 1062
# batch_done: 1063
# batch_done: 1064
# batch_done: 1065
# batch_done: 1066
# batch_done: 1067
# batch_done: 1068
# batch_done: 1069
# batch_done: 1070
# batch_done: 1071
# batch_done: 1072
# batch_done: 1073
# batch_done: 1074
# batch_done: 1075
# batch_done: 1076
# batch_done: 1077
# batch_done: 1078
# batch_done: 1079
# batch_done: 1080
# batch_done: 1081
# batch_done: 1082
# batch_done: 1083
# batch_done: 1084
# batch_done: 1085
# batch_done: 1086
# batch_done: 1087
# batch_done: 1088
# batch_done: 1089
# batch_done: 1090
# batch_done: 1091
# batch_done: 1092
# batch_done: 1093
# batch_done: 1094
# batch_done: 1095
# batch_done: 1096
# batch_done: 1097
# batch_done: 1098
# batch_done: 1099
# batch_done: 1100
# batch_done: 1101
# batch_done: 1102
# batch_done: 1103
# batch_done: 1104
# batch_done: 1105
# batch_done: 1106
# batch_done: 1107
# batch_done: 1108
# batch_done: 1109
# batch_done: 1110
# batch_done: 1111
# batch_done: 1112
# batch_done: 1113
# batch_done: 1114
# batch_done: 1115
# batch_done: 1116
# batch_done: 1117
# batch_done: 1118
# batch_done: 1119
# batch_done: 1120
# batch_done: 1121
# batch_done: 1122
# batch_done: 1123
# batch_done: 1124
# batch_done: 1125
# batch_done: 1126
# batch_done: 1127
# batch_done: 1128
# batch_done: 1129
# batch_done: 1130
# batch_done: 1131
# batch_done: 1132
# batch_done: 1133
# batch_done: 1134
# batch_done: 1135
# batch_done: 1136
# batch_done: 1137
# batch_done: 1138
# batch_done: 1139
# batch_done: 1140
# batch_done: 1141
# batch_done: 1142
# batch_done: 1143
# batch_done: 1144
# batch_done: 1145
# batch_done: 1146
# batch_done: 1147
# batch_done: 1148
# batch_done: 1149
# batch_done: 1150
# batch_done: 1151
# batch_done: 1152
# batch_done: 1153
# batch_done: 1154
# batch_done: 1155
# batch_done: 1156
# batch_done: 1157
# batch_done: 1158
# batch_done: 1159
# batch_done: 1160
# batch_done: 1161
# batch_done: 1162
# batch_done: 1163
# batch_done: 1164
# batch_done: 1165
# batch_done: 1166
# batch_done: 1167
# batch_done: 1168
# batch_done: 1169
# batch_done: 1170
# batch_done: 1171
# batch_done: 1172
# batch_done: 1173
# batch_done: 1174
# batch_done: 1175
# batch_done: 1176
# batch_done: 1177
# batch_done: 1178
# batch_done: 1179
# batch_done: 1180
# batch_done: 1181
# batch_done: 1182
# batch_done: 1183
# batch_done: 1184
# batch_done: 1185
# batch_done: 1186
# batch_done: 1187
# batch_done: 1188
# batch_done: 1189
# batch_done: 1190
# batch_done: 1191
# batch_done: 1192
# batch_done: 1193
# batch_done: 1194
# batch_done: 1195
# batch_done: 1196
# batch_done: 1197
# batch_done: 1198
# batch_done: 1199
# batch_done: 1200
# batch_done: 1201
# batch_done: 1202
# batch_done: 1203
# batch_done: 1204
# batch_done: 1205
# batch_done: 1206
# batch_done: 1207
# batch_done: 1208
# batch_done: 1209
# batch_done: 1210
# batch_done: 1211
# batch_done: 1212
# batch_done: 1213
# batch_done: 1214
# batch_done: 1215
# batch_done: 1216
# batch_done: 1217
# batch_done: 1218
# batch_done: 1219
# batch_done: 1220
# batch_done: 1221
# batch_done: 1222
# batch_done: 1223
# batch_done: 1224
# batch_done: 1225
# batch_done: 1226
# batch_done: 1227
# batch_done: 1228
# batch_done: 1229
# batch_done: 1230
# batch_done: 1231
# batch_done: 1232
# batch_done: 1233
# batch_done: 1234
# batch_done: 1235
# batch_done: 1236
# batch_done: 1237
# batch_done: 1238
# batch_done: 1239
# batch_done: 1240
# batch_done: 1241
# batch_done: 1242
# batch_done: 1243
# batch_done: 1244
# batch_done: 1245
# batch_done: 1246
# batch_done: 1247
# batch_done: 1248
# batch_done: 1249
# batch_done: 1250
# batch_done: 1251
# batch_done: 1252
# batch_done: 1253
# batch_done: 1254
# batch_done: 1255
# batch_done: 1256
# batch_done: 1257
# batch_done: 1258
# batch_done: 1259
# batch_done: 1260
# batch_done: 1261
# batch_done: 1262
# batch_done: 1263
# batch_done: 1264
# batch_done: 1265
# batch_done: 1266
# batch_done: 1267
# batch_done: 1268
# batch_done: 1269
# batch_done: 1270
# batch_done: 1271
# batch_done: 1272
# batch_done: 1273
# batch_done: 1274
# batch_done: 1275
# batch_done: 1276
# batch_done: 1277
# batch_done: 1278
# batch_done: 1279
# batch_done: 1280
# batch_done: 1281
# batch_done: 1282
# batch_done: 1283
# batch_done: 1284
# batch_done: 1285
# batch_done: 1286
# batch_done: 1287
# batch_done: 1288
# batch_done: 1289
# batch_done: 1290
# batch_done: 1291
# batch_done: 1292
# batch_done: 1293
# batch_done: 1294
# batch_done: 1295
# batch_done: 1296
# batch_done: 1297
# batch_done: 1298
# batch_done: 1299
# batch_done: 1300
# batch_done: 1301
# batch_done: 1302
# batch_done: 1303
# batch_done: 1304
# batch_done: 1305
# batch_done: 1306
# batch_done: 1307
# batch_done: 1308
# batch_done: 1309
# batch_done: 1310
# batch_done: 1311
# batch_done: 1312
# batch_done: 1313
# batch_done: 1314
# batch_done: 1315
# batch_done: 1316
# batch_done: 1317
# batch_done: 1318
# batch_done: 1319
# batch_done: 1320
# batch_done: 1321
# batch_done: 1322
# batch_done: 1323
# batch_done: 1324
# batch_done: 1325
# batch_done: 1326
# batch_done: 1327
# batch_done: 1328
# batch_done: 1329
# batch_done: 1330
# batch_done: 1331
# batch_done: 1332
# batch_done: 1333
# batch_done: 1334
# batch_done: 1335
# batch_done: 1336
# batch_done: 1337
# batch_done: 1338
# batch_done: 1339
# batch_done: 1340
# batch_done: 1341
# batch_done: 1342
# batch_done: 1343
# batch_done: 1344
# batch_done: 1345
# batch_done: 1346
# batch_done: 1347
# batch_done: 1348
# batch_done: 1349
# batch_done: 1350
# batch_done: 1351
# batch_done: 1352
# batch_done: 1353
# batch_done: 1354
# batch_done: 1355
# batch_done: 1356
# batch_done: 1357
# batch_done: 1358
# batch_done: 1359
# batch_done: 1360
# batch_done: 1361
# batch_done: 1362
# batch_done: 1363
# batch_done: 1364
# batch_done: 1365
# batch_done: 1366
# batch_done: 1367
# batch_done: 1368
# batch_done: 1369
# batch_done: 1370
# batch_done: 1371
# batch_done: 1372
# batch_done: 1373
# batch_done: 1374
# batch_done: 1375
# batch_done: 1376
# batch_done: 1377
# batch_done: 1378
# batch_done: 1379
# batch_done: 1380
# batch_done: 1381
# batch_done: 1382
# batch_done: 1383
# batch_done: 1384
# batch_done: 1385
# batch_done: 1386
# batch_done: 1387
# batch_done: 1388
# batch_done: 1389
# batch_done: 1390
# batch_done: 1391
# batch_done: 1392
# batch_done: 1393
# batch_done: 1394
# batch_done: 1395
# batch_done: 1396
# batch_done: 1397
# batch_done: 1398
# batch_done: 1399
# batch_done: 1400
# batch_done: 1401
# batch_done: 1402
# batch_done: 1403
# batch_done: 1404
# batch_done: 1405
# batch_done: 1406
# batch_done: 1407
# batch_done: 1408
# batch_done: 1409
# batch_done: 1410
# batch_done: 1411
# batch_done: 1412
# batch_done: 1413
# batch_done: 1414
# batch_done: 1415
# batch_done: 1416
# batch_done: 1417
# batch_done: 1418
# batch_done: 1419
# batch_done: 1420
# batch_done: 1421
# batch_done: 1422
# batch_done: 1423
# batch_done: 1424
# batch_done: 1425
# batch_done: 1426
# batch_done: 1427
# batch_done: 1428
# batch_done: 1429
# batch_done: 1430
# batch_done: 1431
# batch_done: 1432
# batch_done: 1433
# batch_done: 1434
# batch_done: 1435
# batch_done: 1436
# batch_done: 1437
# batch_done: 1438
# batch_done: 1439
# batch_done: 1440
# batch_done: 1441
# batch_done: 1442
# batch_done: 1443
# batch_done: 1444
# batch_done: 1445
# batch_done: 1446
# batch_done: 1447
# batch_done: 1448
# batch_done: 1449
# batch_done: 1450
# batch_done: 1451
# batch_done: 1452
# batch_done: 1453
# batch_done: 1454
# batch_done: 1455
# batch_done: 1456
# batch_done: 1457
# batch_done: 1458
# batch_done: 1459
# batch_done: 1460
# batch_done: 1461
# batch_done: 1462
# batch_done: 1463
# batch_done: 1464
# batch_done: 1465
# batch_done: 1466
# batch_done: 1467
# batch_done: 1468
# batch_done: 1469
# batch_done: 1470
# batch_done: 1471
# batch_done: 1472
# batch_done: 1473
# batch_done: 1474
# batch_done: 1475
# batch_done: 1476
# batch_done: 1477
# batch_done: 1478
# batch_done: 1479
# batch_done: 1480
# batch_done: 1481
# batch_done: 1482
# batch_done: 1483
# batch_done: 1484
# batch_done: 1485
# batch_done: 1486
# batch_done: 1487
# batch_done: 1488
# batch_done: 1489
# batch_done: 1490
# batch_done: 1491
# batch_done: 1492
# batch_done: 1493
# batch_done: 1494
# batch_done: 1495
# batch_done: 1496
# batch_done: 1497
# batch_done: 1498
# batch_done: 1499
# batch_done: 1500
# batch_done: 1501
# batch_done: 1502
# batch_done: 1503
# batch_done: 1504
# batch_done: 1505
# batch_done: 1506
# batch_done: 1507
# batch_done: 1508
# batch_done: 1509
# batch_done: 1510
# batch_done: 1511
# batch_done: 1512
# batch_done: 1513
# batch_done: 1514
# batch_done: 1515
# batch_done: 1516
# batch_done: 1517
# batch_done: 1518
# batch_done: 1519
# batch_done: 1520
# batch_done: 1521
# batch_done: 1522
# batch_done: 1523
# batch_done: 1524
# batch_done: 1525
# batch_done: 1526
# batch_done: 1527
# batch_done: 1528
# batch_done: 1529
# batch_done: 1530
# batch_done: 1531
# batch_done: 1532
# batch_done: 1533
# batch_done: 1534
# batch_done: 1535
# batch_done: 1536
# batch_done: 1537
# batch_done: 1538
# batch_done: 1539
# batch_done: 1540
# batch_done: 1541
# batch_done: 1542
# batch_done: 1543
# batch_done: 1544
# batch_done: 1545
# batch_done: 1546
# batch_done: 1547
# batch_done: 1548
# batch_done: 1549
# batch_done: 1550
# batch_done: 1551
# batch_done: 1552
# batch_done: 1553
# batch_done: 1554
# batch_done: 1555
# batch_done: 1556
# batch_done: 1557
# batch_done: 1558
# batch_done: 1559
# batch_done: 1560
# batch_done: 1561
# batch_done: 1562
# batch_done: 1563
# batch_done: 1564
# batch_done: 1565
# batch_done: 1566
# batch_done: 1567
# batch_done: 1568
# batch_done: 1569
# batch_done: 1570
# batch_done: 1571
# batch_done: 1572
# batch_done: 1573
# batch_done: 1574
# batch_done: 1575
# batch_done: 1576
# batch_done: 1577
# batch_done: 1578
# batch_done: 1579
# batch_done: 1580
# batch_done: 1581
# batch_done: 1582
# batch_done: 1583
# batch_done: 1584
# batch_done: 1585
# batch_done: 1586
# batch_done: 1587
# batch_done: 1588
# batch_done: 1589
# batch_done: 1590
# batch_done: 1591
# batch_done: 1592
# batch_done: 1593
# batch_done: 1594
# batch_done: 1595
# batch_done: 1596
# batch_done: 1597
# batch_done: 1598
# batch_done: 1599
# batch_done: 1600
# batch_done: 1601
# batch_done: 1602
# batch_done: 1603
# batch_done: 1604
# batch_done: 1605
# batch_done: 1606
# batch_done: 1607
# batch_done: 1608
# batch_done: 1609
# batch_done: 1610
# batch_done: 1611
# batch_done: 1612
# batch_done: 1613
# batch_done: 1614
# batch_done: 1615
# batch_done: 1616
# batch_done: 1617
# batch_done: 1618
# batch_done: 1619
# batch_done: 1620
# batch_done: 1621
# batch_done: 1622
# batch_done: 1623
# batch_done: 1624
# batch_done: 1625
# batch_done: 1626
# batch_done: 1627
# batch_done: 1628
# batch_done: 1629
# batch_done: 1630
# batch_done: 1631
# batch_done: 1632
# batch_done: 1633
# batch_done: 1634
# batch_done: 1635
# batch_done: 1636
# batch_done: 1637
# batch_done: 1638
# batch_done: 1639
# batch_done: 1640
# batch_done: 1641
# batch_done: 1642
# batch_done: 1643
# batch_done: 1644
# batch_done: 1645
# batch_done: 1646
# batch_done: 1647
# batch_done: 1648
# batch_done: 1649
# batch_done: 1650
# batch_done: 1651
# batch_done: 1652
# batch_done: 1653
# batch_done: 1654
# batch_done: 1655
# batch_done: 1656
# batch_done: 1657
# batch_done: 1658
# batch_done: 1659
# batch_done: 1660
# batch_done: 1661
# batch_done: 1662
# batch_done: 1663
# batch_done: 1664
# batch_done: 1665
# batch_done: 1666
# batch_done: 1667
# batch_done: 1668
# batch_done: 1669
# batch_done: 1670
# batch_done: 1671
# batch_done: 1672
# batch_done: 1673
# batch_done: 1674
# batch_done: 1675
# batch_done: 1676
# batch_done: 1677
# batch_done: 1678
# batch_done: 1679
# batch_done: 1680
# batch_done: 1681
# batch_done: 1682
# batch_done: 1683
# batch_done: 1684
# batch_done: 1685
# batch_done: 1686
# batch_done: 1687
# batch_done: 1688
# batch_done: 1689
# batch_done: 1690
# batch_done: 1691
# batch_done: 1692
# batch_done: 1693
# batch_done: 1694
# batch_done: 1695
# batch_done: 1696
# batch_done: 1697
# batch_done: 1698
# batch_done: 1699
# batch_done: 1700
# batch_done: 1701
# batch_done: 1702
# batch_done: 1703
# batch_done: 1704
# batch_done: 1705
# batch_done: 1706
# batch_done: 1707
# batch_done: 1708
# batch_done: 1709
# batch_done: 1710
# batch_done: 1711
# batch_done: 1712
# batch_done: 1713
# batch_done: 1714
# batch_done: 1715
# batch_done: 1716
# batch_done: 1717
# batch_done: 1718
# batch_done: 1719
# batch_done: 1720
# batch_done: 1721
# batch_done: 1722
# batch_done: 1723
# batch_done: 1724
# batch_done: 1725
# batch_done: 1726
# batch_done: 1727
# batch_done: 1728
# batch_done: 1729
# batch_done: 1730
# batch_done: 1731
# batch_done: 1732
# batch_done: 1733
# batch_done: 1734
# batch_done: 1735
# batch_done: 1736
# batch_done: 1737
# batch_done: 1738
# batch_done: 1739
# batch_done: 1740
# batch_done: 1741
# batch_done: 1742
# batch_done: 1743
# batch_done: 1744
# batch_done: 1745
# batch_done: 1746
# batch_done: 1747
# batch_done: 1748
# batch_done: 1749
# batch_done: 1750
# batch_done: 1751
# batch_done: 1752
# batch_done: 1753
# batch_done: 1754
# batch_done: 1755
# batch_done: 1756
# batch_done: 1757
# batch_done: 1758
# batch_done: 1759
# batch_done: 1760
# batch_done: 1761
# batch_done: 1762
# batch_done: 1763
# batch_done: 1764
# batch_done: 1765
# batch_done: 1766
# batch_done: 1767
# batch_done: 1768
# batch_done: 1769
# batch_done: 1770
# batch_done: 1771
# batch_done: 1772
# batch_done: 1773
# batch_done: 1774
# batch_done: 1775
# batch_done: 1776
# batch_done: 1777
# batch_done: 1778
# batch_done: 1779
# batch_done: 1780
# batch_done: 1781
# batch_done: 1782
# batch_done: 1783
# batch_done: 1784
# batch_done: 1785
# batch_done: 1786
# batch_done: 1787
# batch_done: 1788
# batch_done: 1789
# batch_done: 1790
# batch_done: 1791
# batch_done: 1792
# batch_done: 1793
# batch_done: 1794
# batch_done: 1795
# batch_done: 1796
# batch_done: 1797
# batch_done: 1798
# batch_done: 1799
# batch_done: 1800
# batch_done: 1801
# batch_done: 1802
# batch_done: 1803
# batch_done: 1804
# batch_done: 1805
# batch_done: 1806
# batch_done: 1807
# batch_done: 1808
# batch_done: 1809
# batch_done: 1810
# batch_done: 1811
# batch_done: 1812
# batch_done: 1813
# batch_done: 1814
# batch_done: 1815
# batch_done: 1816
# batch_done: 1817
# batch_done: 1818
# batch_done: 1819
# batch_done: 1820
# batch_done: 1821
# batch_done: 1822
# batch_done: 1823
# batch_done: 1824
# batch_done: 1825
# batch_done: 1826
# batch_done: 1827
# batch_done: 1828
# batch_done: 1829
# batch_done: 1830
# batch_done: 1831
# batch_done: 1832
# batch_done: 1833
# batch_done: 1834
# batch_done: 1835
# batch_done: 1836
# batch_done: 1837
# batch_done: 1838
# batch_done: 1839
# batch_done: 1840
# batch_done: 1841
# batch_done: 1842
# batch_done: 1843
# batch_done: 1844
# batch_done: 1845
# batch_done: 1846
# batch_done: 1847
# batch_done: 1848
# batch_done: 1849
# batch_done: 1850
# batch_done: 1851
# batch_done: 1852
# batch_done: 1853
# batch_done: 1854
# batch_done: 1855
# batch_done: 1856
# batch_done: 1857
# batch_done: 1858
# batch_done: 1859
# batch_done: 1860
# batch_done: 1861
# batch_done: 1862
# batch_done: 1863
# batch_done: 1864
# batch_done: 1865
# batch_done: 1866
# batch_done: 1867
# batch_done: 1868
# batch_done: 1869
# batch_done: 1870
# batch_done: 1871
# batch_done: 1872
# batch_done: 1873
# batch_done: 1874
# batch_done: 1875
# batch_done: 1876
# batch_done: 1877
# batch_done: 1878
# batch_done: 1879
# batch_done: 1880
# batch_done: 1881
# batch_done: 1882
# batch_done: 1883
# batch_done: 1884
# batch_done: 1885
# batch_done: 1886
# batch_done: 1887
# batch_done: 1888
# batch_done: 1889
# batch_done: 1890
# batch_done: 1891
# batch_done: 1892
# batch_done: 1893
# batch_done: 1894
# batch_done: 1895
# batch_done: 1896
# batch_done: 1897
# batch_done: 1898
# batch_done: 1899
# batch_done: 1900
# batch_done: 1901
# batch_done: 1902
# batch_done: 1903
# batch_done: 1904
# batch_done: 1905
# batch_done: 1906
# batch_done: 1907
# batch_done: 1908
# batch_done: 1909
# batch_done: 1910
# batch_done: 1911
# batch_done: 1912
# batch_done: 1913
# batch_done: 1914
# batch_done: 1915
# batch_done: 1916
# batch_done: 1917
# batch_done: 1918
# batch_done: 1919
# batch_done: 1920
# batch_done: 1921
# batch_done: 1922
# batch_done: 1923
# batch_done: 1924
# batch_done: 1925
# batch_done: 1926
# batch_done: 1927
# batch_done: 1928
# batch_done: 1929
# batch_done: 1930
# batch_done: 1931
# batch_done: 1932
# batch_done: 1933
# batch_done: 1934
# batch_done: 1935
# batch_done: 1936
# batch_done: 1937
# batch_done: 1938
# batch_done: 1939
# batch_done: 1940
# batch_done: 1941
# batch_done: 1942
# batch_done: 1943
# batch_done: 1944
# batch_done: 1945
# batch_done: 1946
# batch_done: 1947
# batch_done: 1948
# batch_done: 1949
# batch_done: 1950
# batch_done: 1951
# batch_done: 1952
# batch_done: 1953
# batch_done: 1954
# batch_done: 1955
# batch_done: 1956
# batch_done: 1957
# batch_done: 1958
# batch_done: 1959
# batch_done: 1960
# batch_done: 1961
# batch_done: 1962
# batch_done: 1963
# batch_done: 1964
# batch_done: 1965
# batch_done: 1966
# batch_done: 1967
# batch_done: 1968
# batch_done: 1969
# batch_done: 1970
# batch_done: 1971
# batch_done: 1972
# batch_done: 1973
# batch_done: 1974
# batch_done: 1975
# batch_done: 1976
# batch_done: 1977
# batch_done: 1978
# batch_done: 1979
# batch_done: 1980
# batch_done: 1981
# batch_done: 1982
# batch_done: 1983
# batch_done: 1984
# batch_done: 1985
# batch_done: 1986
# batch_done: 1987
# batch_done: 1988
# batch_done: 1989
# batch_done: 1990
# batch_done: 1991
# batch_done: 1992
# batch_done: 1993
# batch_done: 1994
# batch_done: 1995
# batch_done: 1996
# batch_done: 1997
# batch_done: 1998
# batch_done: 1999

# %%
df = pd.DataFrame.from_records(app_reviews)
df
# Out:
#                                     reviewId                    userName  \
# 0       a351bae9-8cad-4fa6-96c9-96f208fc6bc1                 Dipu Mandal
# 1       9829f2e0-03bb-4b49-bc71-0135ebed8d1f              Shubham Mhatre
# 2       02620d74-50db-4e54-a07c-c6ca327d6c23                   Rahul Sen
# 3       c20e5f1d-984d-4a0f-ad8e-b9424561afa3              Roshidul Islam
# 4       ef60b70d-b887-4e94-bc35-7a7e622ed6f8        Aftab uddin Talukdar
# ...                                      ...                         ...
# 253195  b340e902-a796-4eaa-8a40-f428819dc290            mpologoma Hassan
# 253196  1322435a-fddf-4f10-9c33-4ffd6efdd9f2                  Alisha Ali
# 253197  ff8a53ed-0e93-445b-9108-644ed7fb2bad               Afroza Akther
# 253198  842b0c99-b2ad-4812-9a17-afa8a69f4316  Mohammadghafoor Khairkhawa
# 253199  2d1fa8ce-1ef0-4a68-94a7-dd7eee2ad8b8            Fatima Enaboakpe
#
#                                                 userImage  \
# 0       https://play-lh.googleusercontent.com/a-/AD5-W...
# 1       https://play-lh.googleusercontent.com/a/AEdFTp...
# 2       https://play-lh.googleusercontent.com/a/AEdFTp...
# 3       https://play-lh.googleusercontent.com/a-/AD5-W...
# 4       https://play-lh.googleusercontent.com/a-/AD5-W...
# ...                                                   ...
# 253195  https://play-lh.googleusercontent.com/a/AEdFTp...
# 253196  https://play-lh.googleusercontent.com/a/AEdFTp...
# 253197  https://play-lh.googleusercontent.com/a/AEdFTp...
# 253198  https://play-lh.googleusercontent.com/a/AEdFTp...
# 253199  https://play-lh.googleusercontent.com/a/AEdFTp...
#
#                                                   content  score  \
# 0                                                     All      5
# 1       I am not able to see linked device option whit...      1
# 2       Pls Give Us Linked Device Option. when we inst...      3
# 3                                                    Nice      5
# 4                                               Very nice      4
# ...                                                   ...    ...
# 253195                                          It's good      2
# 253196  Today my whatsapp account has been blocked too...      1
# 253197                                           Nice App      5
# 253198                                           Good app      5
# 253199  The app is great I can call and chat with anyo...      5
#
#         thumbsUpCount reviewCreatedVersion                  at replyContent  \
# 0                   0            2.23.1.76 2023-02-01 17:45:23         None
# 1                   0                 None 2023-02-01 17:44:14         None
# 2                   0                 None 2023-02-01 17:42:38         None
# 3                   0            2.23.1.76 2023-02-01 17:42:07         None
# 4                   0            2.23.1.76 2023-02-01 17:41:59         None
# ...               ...                  ...                 ...          ...
# 253195              0           2.22.17.76 2022-11-12 01:42:43         None
# 253196              0           2.22.23.77 2022-11-12 01:41:36         None
# 253197              0                 None 2022-11-12 01:41:32         None
# 253198              0                 None 2022-11-12 01:41:28         None
# 253199              0           2.22.23.77 2022-11-12 01:40:55         None
#
#        repliedAt
# 0           None
# 1           None
# 2           None
# 3           None
# 4           None
# ...          ...
# 253195      None
# 253196      None
# 253197      None
# 253198      None
# 253199      None
#
# [253200 rows x 10 columns]

# %%
df.to_csv('whatsapp_reviews.csv',index=False)

# %%
df.score.value_counts()
# Out:
# 5    158368
# 1     41373
# 4     24801
# 3     16439
# 2     12219
# Name: score, dtype: int64
